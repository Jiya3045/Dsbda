# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("C:/Users/shree/Desktop/ipl22_report.csv")

# %%
df
# Out:
#     match_id           date                                         venue  \
# 0          1  March 26,2022                      Wankhede Stadium, Mumbai
# 1          2  March 27,2022                     Brabourne Stadium, Mumbai
# 2          3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3          4  March 28,2022                      Wankhede Stadium, Mumbai
# 4          5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
# ..       ...            ...                                           ...
# 69        70    May 22,2022                      Wankhede Stadium, Mumbai
# 70        71    May 24,2022                         Eden Gardens, Kolkata
# 71        72    May 25,2022                         Eden Gardens, Kolkata
# 72        73    May 27,2022              Narendra Modi Stadium, Ahmedabad
# 73        74    May 29,2022              Narendra Modi Stadium, Ahmedabad
#
#         team1      team2    stage toss_winner toss_decision  first_ings_score  \
# ...

# %%
df.head(4)
# Out:
#    match_id           date                               venue     team1  \
# 0         1  March 26,2022            Wankhede Stadium, Mumbai   Chennai
# 1         2  March 27,2022           Brabourne Stadium, Mumbai     Delhi
# 2         3  March 27,2022  Dr DY Patil Sports Academy, Mumbai  Banglore
# 3         4  March 28,2022            Wankhede Stadium, Mumbai   Gujarat
#
#      team2  stage toss_winner toss_decision  first_ings_score  \
# 0  Kolkata  Group     Kolkata         Field               131
# 1   Mumbai  Group       Delhi         Field               177
# 2   Punjab  Group      Punjab         Field               205
# 3  Lucknow  Group     Gujarat         Field               158
#
#    first_ings_wkts  second_ings_score  second_ings_wkts match_winner   won_by  \
# 0                5                133                 4      Kolkata  Wickets
# 1                5                179                 6        Delhi  Wickets
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
df.describe()
# Out:
#         match_id  first_ings_score  first_ings_wkts  second_ings_score  \
# count  74.000000         74.000000        74.000000          74.000000
# mean   37.500000        171.121622         6.135135         158.540541
# std    21.505813         29.048355         2.222699          29.299207
# min     1.000000         68.000000         0.000000          72.000000
# 25%    19.250000        154.250000         5.000000         142.750000
# 50%    37.500000        169.500000         6.000000         160.000000
# 75%    55.750000        192.750000         8.000000         176.000000
# max    74.000000        222.000000        10.000000         211.000000
#
#        second_ings_wkts     margin   highscore
# count         74.000000  74.000000   74.000000
# mean           6.175676  16.972973   71.716216
# std            2.639832  19.651047   20.705052
# min            1.000000   2.000000   28.000000
# 25%            4.000000   5.250000   57.000000
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=74, step=1)

# %%
df.shape
# Out:
# (74, 20)

# %%
df.columns.names
# Out:
# FrozenList([None])

# %%
df.columns.values
# Out:
# array(['match_id', 'date', 'venue', 'team1', 'team2', 'stage',
#        'toss_winner', 'toss_decision', 'first_ings_score',
#        'first_ings_wkts', 'second_ings_score', 'second_ings_wkts',
#        'match_winner', 'won_by', 'margin', 'player_of_the_match',
#        'top_scorer', 'highscore', 'best_bowling', 'best_bowling_figure'],
#       dtype=object)

# %%
df.dtypes
# Out:
# match_id                int64
# date                   object
# venue                  object
# team1                  object
# team2                  object
# stage                  object
# toss_winner            object
# toss_decision          object
# first_ings_score        int64
# first_ings_wkts         int64
# second_ings_score       int64
# second_ings_wkts        int64
# match_winner           object
# won_by                 object
# margin                  int64
# player_of_the_match    object
# top_scorer             object
# highscore               int64
# best_bowling           object
# best_bowling_figure    object
# dtype: object

# %%
df.shape
# Out:
# (74, 20)

# %%
df.columns
# Out:
# Index(['match_id', 'date', 'venue', 'team1', 'team2', 'stage', 'toss_winner',
#        'toss_decision', 'first_ings_score', 'first_ings_wkts',
#        'second_ings_score', 'second_ings_wkts', 'match_winner', 'won_by',
#        'margin', 'player_of_the_match', 'top_scorer', 'highscore',
#        'best_bowling', 'best_bowling_figure'],
#       dtype='object')

# %%
df.iloc[20]
# Out:
# match_id                                               21
# date                                         April11,2022
# venue                  Dr DY Patil Sports Academy, Mumbai
# team1                                             Gujarat
# team2                                           Hyderabad
# stage                                               Group
# toss_winner                                     Hyderabad
# toss_decision                                       Field
# first_ings_score                                      162
# first_ings_wkts                                         7
# second_ings_score                                     168
# second_ings_wkts                                        2
# match_winner                                    Hyderabad
# won_by                                            Wickets
# margin                                                  8
# player_of_the_match                       Kane Williamson
# ...

# %%
df.toss_winner.iloc[20]
# Out:
# 'Hyderabad'

# %%
df.iloc[:,3:7]
# Out:
#         team1      team2    stage toss_winner
# 0     Chennai    Kolkata    Group     Kolkata
# 1       Delhi     Mumbai    Group       Delhi
# 2    Banglore     Punjab    Group      Punjab
# 3     Gujarat    Lucknow    Group     Gujarat
# 4   Hyderabad  Rajasthan    Group   Hyderabad
# ..        ...        ...      ...         ...
# 69  Hyderabad     Punjab    Group   Hyderabad
# 70    Gujarat  Rajasthan  Playoff     Gujarat
# 71   Banglore    Lucknow  Playoff     Lucknow
# 72   Banglore  Rajasthan  Playoff   Rajasthan
# 73    Gujarat  Rajasthan    Final   Rajasthan
#
# [74 rows x 4 columns]

# %%
df.iloc[:101,1:5]
# Out:
#              date                                         venue      team1  \
# 0   March 26,2022                      Wankhede Stadium, Mumbai    Chennai
# 1   March 27,2022                     Brabourne Stadium, Mumbai      Delhi
# 2   March 27,2022            Dr DY Patil Sports Academy, Mumbai   Banglore
# 3   March 28,2022                      Wankhede Stadium, Mumbai    Gujarat
# 4   March 29,2022  Maharashtra Cricket Association Stadium,Pune  Hyderabad
# ..            ...                                           ...        ...
# 69    May 22,2022                      Wankhede Stadium, Mumbai  Hyderabad
# 70    May 24,2022                         Eden Gardens, Kolkata    Gujarat
# 71    May 25,2022                         Eden Gardens, Kolkata   Banglore
# 72    May 27,2022              Narendra Modi Stadium, Ahmedabad   Banglore
# 73    May 29,2022              Narendra Modi Stadium, Ahmedabad    Gujarat
#
#         team2
# 0     Kolkata
# 1      Mumbai
# 2      Punjab
# ...

# %%
df.iloc[:5,7:6]
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df.highscore.min()
# Out:
# 28

# %%
df.second_ings_wkts	.sum()
# Out:
# np.int64(457)
