# %% [markdown]
# Name: Jiya Jethwani Class: TE (B1) Roll no: 13218 Title: 1. Creation of Dataset using Microsoft Excel,  2. Identification and Handling of Outliers, 3. Data Transformation for the purpose of : a-- To change the scale for better understanding, b-- To decrease the skewness and convert distribution into normal distribution.

# %%
import pandas as pd

# %%
df=pd.read_csv('C:/Users/shree/Desktop/dsbdaprac2.csv')

# %%
df
# Out:
#     Math_Score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         60.0           88.0             66               84            2018
# 1         73.0            NaN             80               77            2020
# 2         65.0           81.0             79               77            2018
# 3          NaN           88.0             65               76            2020
# 4          NaN           90.0             63               79            2021
# 5          NaN           75.0             74               75            2018
# 6         73.0           93.0             71               81            2021
# 7          NaN           77.0             77               83            2018
# 8         70.0           89.0             78               83            2020
# 9         72.0           93.0             73               85            2021
# 10        78.0            NaN             76               78            2019
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     Math_Score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         60.0           88.0             66               84            2018
# 1         73.0            NaN             80               77            2020
# 2         65.0           81.0             79               77            2018
# 3          NaN           88.0             65               76            2020
# 4          NaN           90.0             63               79            2021
# 5          NaN           75.0             74               75            2018
# 6         73.0           93.0             71               81            2021
# 7          NaN           77.0             77               83            2018
# 8         70.0           89.0             78               83            2020
# 9         72.0           93.0             73               85            2021
# 10        78.0            NaN             76               78            2019
# ...

# %%
df.isnull().sum()
# Out:
# Math_Score               4
# Reading_score            3
# Writing_score            0
# Placement_score          0
# Club_Join_Date           0
# Placement_Offer_Count    4
# dtype: int64

# %%
df.Math_Score.max()
# Out:
# 78.0

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Math_Score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         60.0           88.0             66               84            2018
# 1         73.0            NaN             80               77            2020
# 2         65.0           81.0             79               77            2018
# 3          NaN           88.0             65               76            2020
# 4          NaN           90.0             63               79            2021
# 5          NaN           75.0             74               75            2018
# 6         73.0           93.0             71               81            2021
# 7          NaN           77.0             77               83            2018
# 8         70.0           89.0             78               83            2020
# 9         72.0           93.0             73               85            2021
# 10        78.0            NaN             76               78            2019
# ...

# %%
x=df.Math_Score.mean()

# %%
df.Math_Score.fillna(x,inplace=True)
# Out:
# C:\Users\shree\AppData\Local\Temp\ipykernel_7300\2143244766.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Math_Score.fillna(x,inplace=True)

# %%
df
# Out:
#     Math_Score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    60.000000           88.0             66               84            2018
# 1    73.000000            NaN             80               77            2020
# 2    65.000000           81.0             79               77            2018
# 3    67.821429           88.0             65               76            2020
# 4    67.821429           90.0             63               79            2021
# 5    67.821429           75.0             74               75            2018
# 6    73.000000           93.0             71               81            2021
# 7    67.821429           77.0             77               83            2018
# 8    70.000000           89.0             78               83            2020
# 9    72.000000           93.0             73               85            2021
# 10   78.000000            NaN             76               78            2019
# ...

# %%
y=df.Reading_score.mean()

# %%
df.Reading_score.fillna(y,inplace=True)
# Out:
# C:\Users\shree\AppData\Local\Temp\ipykernel_7300\325959419.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Reading_score.fillna(y,inplace=True)

# %%
df
# Out:
#     Math_Score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    60.000000      88.000000             66               84            2018
# 1    73.000000      85.275862             80               77            2020
# 2    65.000000      81.000000             79               77            2018
# 3    67.821429      88.000000             65               76            2020
# 4    67.821429      90.000000             63               79            2021
# 5    67.821429      75.000000             74               75            2018
# 6    73.000000      93.000000             71               81            2021
# 7    67.821429      77.000000             77               83            2018
# 8    70.000000      89.000000             78               83            2020
# 9    72.000000      93.000000             73               85            2021
# 10   78.000000      85.275862             76               78            2019
# ...

# %%
z=df.Writing_score.mean()

# %%
df.Writing_score.fillna(z,inplace=True)
# Out:
# C:\Users\shree\AppData\Local\Temp\ipykernel_7300\3823014896.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Writing_score.fillna(z,inplace=True)

# %%
df
# Out:
#     Math_Score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    60.000000      88.000000             66               84            2018
# 1    73.000000      85.275862             80               77            2020
# 2    65.000000      81.000000             79               77            2018
# 3    67.821429      88.000000             65               76            2020
# 4    67.821429      90.000000             63               79            2021
# 5    67.821429      75.000000             74               75            2018
# 6    73.000000      93.000000             71               81            2021
# 7    67.821429      77.000000             77               83            2018
# 8    70.000000      89.000000             78               83            2020
# 9    72.000000      93.000000             73               85            2021
# 10   78.000000      85.275862             76               78            2019
# ...

# %%
df.iloc[11:12,3:4].fillna(45,inplace=True)

# %%
df.Club_Join_Date.fillna(2020,inplace=True)
# Out:
# C:\Users\shree\AppData\Local\Temp\ipykernel_7300\502560848.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Club_Join_Date.fillna(2020,inplace=True)

# %%
df
# Out:
#     Math_Score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    60.000000      88.000000             66               84            2018
# 1    73.000000      85.275862             80               77            2020
# 2    65.000000      81.000000             79               77            2018
# 3    67.821429      88.000000             65               76            2020
# 4    67.821429      90.000000             63               79            2021
# 5    67.821429      75.000000             74               75            2018
# 6    73.000000      93.000000             71               81            2021
# 7    67.821429      77.000000             77               83            2018
# 8    70.000000      89.000000             78               83            2020
# 9    72.000000      93.000000             73               85            2021
# 10   78.000000      85.275862             76               78            2019
# ...

# %%
df.Placement_score.fillna(234,inplace=True)
# Out:
# C:\Users\shree\AppData\Local\Temp\ipykernel_7300\2710582630.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Placement_score.fillna(234,inplace=True)

# %%
df
# Out:
#     Math_Score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    60.000000      88.000000             66               84            2018
# 1    73.000000      85.275862             80               77            2020
# 2    65.000000      81.000000             79               77            2018
# 3    67.821429      88.000000             65               76            2020
# 4    67.821429      90.000000             63               79            2021
# 5    67.821429      75.000000             74               75            2018
# 6    73.000000      93.000000             71               81            2021
# 7    67.821429      77.000000             77               83            2018
# 8    70.000000      89.000000             78               83            2020
# 9    72.000000      93.000000             73               85            2021
# 10   78.000000      85.275862             76               78            2019
# ...

# %%
df.Placement_Offer_Count.fillna(10,inplace=True)
# Out:
# C:\Users\shree\AppData\Local\Temp\ipykernel_7300\40480579.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Placement_Offer_Count.fillna(10,inplace=True)

# %%
df
# Out:
#     Math_Score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    60.000000      88.000000             66               84            2018
# 1    73.000000      85.275862             80               77            2020
# 2    65.000000      81.000000             79               77            2018
# 3    67.821429      88.000000             65               76            2020
# 4    67.821429      90.000000             63               79            2021
# 5    67.821429      75.000000             74               75            2018
# 6    73.000000      93.000000             71               81            2021
# 7    67.821429      77.000000             77               83            2018
# 8    70.000000      89.000000             78               83            2020
# 9    72.000000      93.000000             73               85            2021
# 10   78.000000      85.275862             76               78            2019
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Math_Score', 'Reading_score', 'Writing_score', 'Placement_score',
#        'Club_Join_Date', 'Placement_Offer_Count'],
#       dtype='object')

# %%
col=['Math_Score', 'Reading_score', 'Writing_score', 'Placement_score',
       'Club_Join_Date', 'Placement_Offer_Count']

# %%
import matplotlib.pyplot as plt

# %%
df.boxplot(col)
# Out:
# <Axes: >

# %%
col1=['Math_Score', 'Reading_score', 'Writing_score', 'Placement_score'
      ]

# %%
df.boxplot(col1)
# Out:
# <Axes: >

# %%
plt.show()

# %%
fig,ax=plt.subplots(figsize=(18,10))

# %%
ax.scatter(df['Placement_score'],df['Placement_Offer_Count'])

# %%
ax.scatter(df['Placement_score'],df['Placement_Offer_Count'])

# %%
plt.show()

# %%
df.describe()
# Out:
#        Math_Score  Reading_score  Writing_score  Placement_score  \
# count   32.000000      32.000000      32.000000        32.000000
# mean    67.821429      85.275862      68.562500        80.500000
# std      5.442091       5.192405       6.158851         3.321484
# min     60.000000      75.000000      61.000000        75.000000
# 25%     63.000000      81.000000      63.000000        77.750000
# 50%     67.821429      85.637931      66.500000        81.000000
# 75%     72.250000      89.000000      74.000000        83.250000
# max     78.000000      94.000000      80.000000        85.000000
#
#        Club_Join_Date  Placement_Offer_Count
# count       32.000000              32.000000
# mean      2019.343750               3.031250
# std          1.207754               2.681891
# min       2018.000000               2.000000
# 25%       2018.000000               2.000000
# 50%       2019.000000               2.000000
# 75%       2020.250000               2.000000
# ...

# %%
import numpy as np

# %%
q1=np.percentile(df.Math_Score,25)

# %%
q2=np.percentile(df.Math_Score,50)

# %%
q3=np.percentile(df.Math_Score,75)

# %%
IQR=q3-q2

# %%
IQR
# Out:
# np.float64(4.428571428571431)

# %%
upper_bod= q3 + 2.5*IQR

# %%
upper_bod
# Out:
# np.float64(83.32142857142858)

# %%
lower_bod = q1- 1.5*IQR

# %%
lower_bod
# Out:
# np.float64(56.357142857142854)

# %%
from scipy import stats

# %%
s = np.abs(stats.zscore(df['Placement_Offer_Count']))

# %%
s
# Out:
# array([0.3906762 , 0.3906762 , 0.3906762 , 0.3906762 , 0.3906762 ,
#        0.3906762 , 0.3906762 , 2.640024  , 2.640024  , 2.640024  ,
#        2.640024  , 0.3906762 , 0.3906762 , 0.3906762 , 0.3906762 ,
#        0.3906762 , 0.3906762 , 0.3906762 , 0.3906762 , 0.3906762 ,
#        0.3906762 , 0.3906762 , 0.3906762 , 0.3906762 , 0.3906762 ,
#        0.3906762 , 0.3906762 , 0.3906762 , 0.3906762 , 0.3906762 ,
#        0.01183867, 0.3906762 ])
