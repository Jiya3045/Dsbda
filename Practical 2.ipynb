# %%
import numpy as np

# %%
x=np.array([[2,3,4,5],[34,6,10,6],[12,43,9,3]])

# %%
print(x)
# Out:
# [[ 2  3  4  5]
#  [34  6 10  6]
#  [12 43  9  3]]

# %%
print("value at [0][0] and [0][1] : ",x[0:1,0:2])
# Out:
# value at [0][0] and [0][1] :  [[2 3]]

# %%
print("value at[0][1] , [0][2] , [0][3] :",x[0:1,1:4])
# Out:
# value at[0][1] , [0][2] , [0][3] : [[3 4 5]]

# %%
print("value at[1][0] :",x[1:2, 0:2])
# Out:
# value at[1][0] : [[34  6]]

# %%
print("value at[1][1],[1,2],[1,3] :",x[1:5,1:4])
# Out:
# value at[1][1],[1,2],[1,3] : [[ 6 10  6]
#  [43  9  3]]

# %%
print(x[1:3,1:4])
# Out:
# [[ 6 10  6]
#  [43  9  3]]

# %%
y=np.array([[8,20,24,25],[30,35,36,40],[42,43,47,50],[49,51,52,53]])

# %%
print(y)
# Out:
# [[ 8 20 24 25]
#  [30 35 36 40]
#  [42 43 47 50]
#  [49 51 52 53]]

# %%
print("value as 35,36,43,47:",y[1:3,1:3])
# Out:
# value as 35,36,43,47: [[35 36]
#  [43 47]]

# %%
print(y[2: ,3: ])
# Out:
# [[50]
#  [53]]

# %%
print(y[0:6 ,2: ])
# Out:
# [[24 25]
#  [36 40]
#  [47 50]
#  [52 53]]
