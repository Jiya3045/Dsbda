# %%
print('hello world')
# Out:
# hello world

# %%
x=[10,20,30,40]

# %%
x.insert(2,4)

# %%
print(x)
# Out:
# [10, 20, 4, 30, 40]

# %%
p={}

# %%
print("Type of p=",type(p))
# Out:
# Type of p= <class 'dict'>

# %%
print("For Display of Empty set")
# Out:
# For Display of Empty set

# %%
p=set()

# %%
print("Ëmpty set",p)
# Out:
# Ëmpty set set()

# %%
print("Dictionary Data")
# Out:
# Dictionary Data

# %%
product={"pid":101,"pname":'book'}

# %%
print("Data Iin Dictionary :",product)
# Out:
# Data Iin Dictionary : {'pid': 101, 'pname': 'book'}

# %%
product['price']=300

# %%
print("Data Iin Dictionary :",product)
# Out:
# Data Iin Dictionary : {'pid': 101, 'pname': 'book', 'price': 300}

# %%
a=(3,5,8,2,1)

# %%
x=list(a)

# %%
x.append(34)

# %%
print("Data in List:",x)
# Out:
# Data in List: [3, 5, 8, 2, 1, 34]

# %%
student={"Rollno":101,"Name":'Ram'}

# %%
print("Name of student:",student["Name"])
# Out:
# Name of student: Ram
